# %%
import requests
import pandas as pd

def get_stock_data(symbol, start_date, end_date):
    api_key = 'LAL6ITXFCRIWX7Y6'
    url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol={symbol}&apikey={api_key}&outputsize=full'
    response = requests.get(url)
    print(response.json())
    data = response.json()['Time Series (Daily)']
    df = pd.DataFrame(columns=['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'])
    for date in data:
        if start_date <= date <= end_date:
            row = [date, float(data[date]['1. open']), float(data[date]['2. high']), float(data[date]['3. low']),
                   float(data[date]['4. close']), float(data[date]['5. adjusted close']), float(data[date]['6. volume'])]
            df.loc[len(df)] = row
    return df

# Ejemplo de uso


df = get_stock_data('AAPL', '2022-01-01', '2022-05-01')
print(df)
# Out:
# {'Information': 'Thank you for using Alpha Vantage! This is a premium endpoint. You may subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly unlock all premium endpoints'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-1163103e3537> in <cell line: 21>()
#      19
#      20
# ---> 21 df = get_stock_data('AAPL', '2022-01-01', '2022-05-01')
#      22 print(df)
#
# <ipython-input-2-1163103e3537> in get_stock_data(symbol, start_date, end_date)
#       7     response = requests.get(url)
#       8     print(response.json())
# ----> 9     data = response.json()['Time Series (Daily)']
#      10     df = pd.DataFrame(columns=['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'])
#      11     for date in data:
#
# KeyError: 'Time Series (Daily)'

# %%
import pandas_ta as ta
def calculate_technical_indicators(stock_data, sma_length=20, rsi_length=14, bb_length=20, bb_std=2):
    stock_data.ta.sma(length=sma_length, append=True)
    stock_data.ta.rsi(length=rsi_length, append=True)
    stock_data.ta.bbands(length=bb_length, std=bb_std, append=True)
    stock_data.ta.macd(append=True)
    return stock_data

ticker = "AAPL"
start_date = "2020-01-01"
end_date = "2021-01-01"

stock_data = get_stock_data(ticker, start_date, end_date)
stock_data = calculate_technical_indicators(stock_data)

print(stock_data.tail())
# Out:
#            Date    Open    High     Low   Close  Adj Close      Volume  \
# 248  2020-01-08  297.16  304.44  297.16  303.19  74.040340  33090946.0
# 249  2020-01-07  299.84  300.90  297.48  298.39  72.868158  27877655.0
# 250  2020-01-06  293.79  299.96  292.75  299.80  73.212487  29644644.0
# 251  2020-01-03  297.15  300.58  296.50  297.43  72.633722  36633878.0
# 252  2020-01-02  296.24  300.60  295.19  300.35  73.346799  33911864.0
#
#        SMA_20     RSI_14  BBL_20_2.0  BBM_20_2.0  BBU_20_2.0  BBB_20_2.0  \
# 248  315.1615  43.851299  304.195133    315.1615  326.127867    6.959205
# 249  314.0085  40.843607  301.229957    314.0085  326.787043    8.138979
# 250  313.0560  42.099905  299.079219    313.0560  327.032781    8.929253
# 251  312.4945  40.541415  297.032977    312.4945  327.956023    9.895549
# 252  312.0365  43.325178  295.728957    312.0365  328.344043   10.452331
#
#      BBP_20_2.0  MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9
# ...

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218908 sha256=5c9c1b8fb9d89ddd61699402ad78ba6360f9869349371d285c69a3344ecdafe9
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas_ta
# ...

# %%
df
# Out:
#           Date    Open     High     Low   Close   Adj Close       Volume
# 0   2022-04-29  161.84  166.200  157.25  157.65  156.483984  131747571.0
# 1   2022-04-28  159.25  164.515  158.93  163.64  162.429681  130216792.0
# 2   2022-04-27  155.91  159.790  155.38  156.57  155.411972   88063191.0
# 3   2022-04-26  162.25  162.340  156.72  156.80  155.640271   94008394.0
# 4   2022-04-25  161.12  163.170  158.46  162.88  161.675302   96046376.0
# ..         ...     ...      ...     ...     ...         ...          ...
# 77  2022-01-07  172.89  174.140  171.03  172.17  170.678775   86709147.0
# 78  2022-01-06  172.70  175.300  171.64  172.00  170.510247   96903955.0
# 79  2022-01-05  179.61  180.170  174.64  174.92  173.404956   94537602.0
# 80  2022-01-04  182.63  182.940  179.12  179.70  178.143555   99310438.0
# 81  2022-01-03  177.83  182.880  177.71  182.01  180.433547  104701220.0
#
# [82 rows x 7 columns]

# %%
calcular_indicadores_tecnicos(df, ma_length=20, rsi_length=14, bb_length=20, bb_std=2, macd_fast=12, macd_slow=26, macd_signal=9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5f7e05636479> in <cell line: 1>()
# ----> 1 calcular_indicadores_tecnicos(df, ma_length=20, rsi_length=14, bb_length=20, bb_std=2, macd_fast=12, macd_slow=26, macd_signal=9)
#
# <ipython-input-17-66dfcd5e609a> in calcular_indicadores_tecnicos(df, ma_length, rsi_length, bb_length, bb_std, macd_fast, macd_slow, macd_signal)
#       3 def calcular_indicadores_tecnicos(df, ma_length, rsi_length, bb_length, bb_std, macd_fast, macd_slow, macd_signal):
#       4     # Calcular medias móviles
# ----> 5     df['ma'] = sma(df['Close'], timeperiod=ma_length)
#       6     df['ema'] = ta.ema(df['Close'], timeperiod=ma_length)
#       7
#
# NameError: name 'sma' is not defined

# %%
# !pip install --upgrade ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install TA-Lib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.6/272.6 kB 9.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for TA-Lib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for TA-Lib
# Failed to build TA-Lib
# ERROR: Could not build wheels for TA-Lib, which is required to install pyproject.toml-based projects

# %%
# !pip install alpha_vantage
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.3 MB/s eta 0:00:00
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-71b0df2091df> in <cell line: 1>()
# ----> 1 df_apple = get_financials('AAPL', '2023-01-01', '2023-05-01')
#       2 print(df_apple.head())
#       3 #Esto devolverá un DataFrame con los datos financieros y de precios para la empresa APPLE desde el 1 de enero de 2022 hasta el 1 de mayo de 2022.
#
# <ipython-input-1-72452407fdd0> in get_financials(ticker, start_date, end_date)
#      13     # Obtener los datos financieros de la empresa
#      14     ticker_info = yf.Ticker(ticker)
# ---> 15     financials = ticker_info.financials
#      16     financials = financials.loc[start_date:end_date]
#      17
#
# /usr/local/lib/python3.10/dist-packages/yfinance/ticker.py in financials(self)
#     172     @property
#     173     def financials(self) -> _pd.DataFrame:
# --> 174         return self.income_stmt
#     175
# ...
